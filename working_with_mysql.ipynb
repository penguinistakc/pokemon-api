# %% [markdown]
# # Working with Databases: MySQL

# %% [markdown]
# ## Using mysql.connector

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="password",
    database="baseball"
)

# %%
query = '''SELECT nameFirst, nameLast, weight, year(debut)
FROM Master
ORDER BY weight DESC
LIMIT 5'''

# %%
cursor = conn.cursor()
cursor.execute(query)
results = cursor.fetchall()
cursor.close()
conn.close()

# %%
results

# %% [markdown]
# ## Using PyMySQL

# %%
import pymysql

# %%
conn = pymysql.connect(
        host="127.0.0.1",
    user="root",
    password="password",
    database="baseball"
)

# %%
query = '''SELECT nameFirst, nameLast, weight, year(debut)
FROM Master
ORDER BY weight DESC
LIMIT 5'''

# %% [markdown]
# ### Or you can use a *context manager*, which uses the `with` statement and handles opening and closing the cursor automatically (the connection still needs to be manually closed).

# %%
with conn.cursor() as cursor:
    cursor.execute(query)
    context_results = cursor.fetchall()
conn.close()

# %%
context_results
# Out:
# (('John', 'McSherry', 351, None),
#  ('Walter', 'Young', 320, 2005),
#  ('Jumbo', 'Diaz', 315, 2014),
#  ('CC', 'Sabathia', 300, 2001),
#  ('Jumbo', 'Brown', 295, 1925))
